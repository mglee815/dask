# %%
import pandas as pd
import dask.dataframe as dd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/mglee/VSCODE/git_folder/dask/dask_UTP.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B141.223.144.85/home/mglee/VSCODE/git_folder/dask/dask_UTP.ipynb#ch0000000vscode-remote?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell://ssh-remote%2B141.223.144.85/home/mglee/VSCODE/git_folder/dask/dask_UTP.ipynb#ch0000000vscode-remote?line=1'>2</a> import dask.dataframe as dd
#
# File ~/.conda/envs/svmglee/lib/python3.8/site-packages/dask/dataframe/__init__.py:3, in <module>
#       <a href='file:///home/mglee/.conda/envs/svmglee/lib/python3.8/site-packages/dask/dataframe/__init__.py?line=0'>1</a> try:
#       <a href='file:///home/mglee/.conda/envs/svmglee/lib/python3.8/site-packages/dask/dataframe/__init__.py?line=1'>2</a>     from dask.base import compute
# ...
